# %%
import numpy as np
import pandas as pd
from datetime import datetime

# %% [markdown]
# # UFC Matches Analysis
#
# ### ufc_event_details
#     - EVENT, BOUT, DATE, LOCATION
#
# ### ufc_fight_results.csv
#     - EVENT, BOUT, OUTCOME, WEIGHTCLASS, METHOD, ROUND, TIME FORMAT
#
# ### ufc_fight_stats.csv
#     BOUT, ROUND, FIGHTER, KD, SIG.STR., SIG.STR.%, TOTAL STR., TD, TD%, SUB.ATT, REV., CTRL, HEAD, BODY, LEG, DISTANCE, CLINCH, GROUND
#
# ### ufc_fighter_details.csv
#     FIRST, LAST, NICKNAME
#
# ### ufc_fighter_tott.csv
#     FIGHTER, HEIGHT, WEIGHT, REACH, STANCE, DOB

# %%
df_fight_stats = pd.read_csv('ufc_fight_stats.csv')
df_fighter_details = pd.read_csv('ufc_fighter_details.csv')
df_ufc_event_details = pd.read_csv('ufc_event_details.csv')
df_ufc_fight_results = pd.read_csv('ufc_fight_results.csv')
df_ufc_fighter_tott = pd.read_csv('ufc_fighter_tott.csv')

# %%
print(df_fight_stats.info())
print(df_fighter_details.info())
print(df_ufc_event_details.info())
print(df_ufc_fight_results.info())
print(df_ufc_fighter_tott.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37302 entries, 0 to 37301
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EVENT       37302 non-null  object
#  1   BOUT        37302 non-null  object
#  2   ROUND       37260 non-null  object
#  3   FIGHTER     37260 non-null  object
#  4   KD          37260 non-null  float64
#  5   SIG.STR.    37260 non-null  object
#  6   SIG.STR. %  37260 non-null  object
#  7   TOTAL STR.  37260 non-null  object
#  8   TD          37260 non-null  object
#  9   TD %        37260 non-null  object
#  10  SUB.ATT     37260 non-null  float64
#  11  REV.        37260 non-null  float64
#  12  CTRL        37260 non-null  object
#  13  HEAD        37260 non-null  object
#  14  BODY        37260 non-null  object
#  15  LEG         37260 non-null  object
#  16  DISTANCE    37260 non-null  object
#  17  CLINCH      37260 non-null  object
#  18  GROUND      37260 non-null  object
# dtypes: float64(3), object(16)
# memory usage: 5.4+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4264 entries, 0 to 4263
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   FIRST     4250 non-null   object
#  1   LAST      4264 non-null   object
#  2   NICKNAME  2352 non-null   object
#  3   URL       4264 non-null   object
# dtypes: object(4)
# memory usage: 133.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 715 entries, 0 to 714
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   EVENT     715 non-null    object
#  1   URL       715 non-null    object
#  2   DATE      715 non-null    object
#  3   LOCATION  715 non-null    object
# dtypes: object(4)
# memory usage: 22.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7935 entries, 0 to 7934
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EVENT        7935 non-null   object
#  1   BOUT         7935 non-null   object
#  2   OUTCOME      7935 non-null   object
#  3   WEIGHTCLASS  7935 non-null   object
#  4   METHOD       7935 non-null   object
#  5   ROUND        7935 non-null   int64
#  6   TIME         7935 non-null   object
#  7   TIME FORMAT  7935 non-null   object
#  8   REFEREE      7901 non-null   object
#  9   DETAILS      7858 non-null   object
#  10  URL          7935 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 682.0+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   FIGHTER  4269 non-null   object
#  1   HEIGHT   4269 non-null   object
#  2   WEIGHT   4269 non-null   object
#  3   REACH    4269 non-null   object
#  4   STANCE   2943 non-null   object
#  5   DOB      4269 non-null   object
#  6   URL      4269 non-null   object
# dtypes: object(7)
# memory usage: 233.6+ KB
# None

# %% [markdown]
# ## Cleaning df_ufc_event_details

# %%
df_ufc_event_details = df_ufc_event_details.drop(columns='URL')

# %%
df_ufc_event_details['EVENT'] = df_ufc_event_details['EVENT'].str.strip().str.lower()

# %%
def cv_date(date_str):
    date_ob = datetime.strptime(date_str,"%B %d, %Y")
    return date_ob.strftime("%m-%d-%y")
df_ufc_event_details['DATE']=df_ufc_event_details['DATE'].apply(cv_date)

# %%
df_ufc_event_details
# Out:
#                                       EVENT      DATE  \
# 0    ufc fight night: covington vs. buckley  12-14-24
# 1              ufc 310: pantoja vs. asakura  12-07-24
# 2       ufc fight night: yan vs. figueiredo  11-23-24
# 3                 ufc 309: jones vs. miocic  11-16-24
# 4         ufc fight night: magny vs. prates  11-09-24
# ..                                      ...       ...
# 710              ufc 6: clash of the titans  07-14-95
# 711          ufc 5: the return of the beast  04-07-95
# 712          ufc 4: revenge of the warriors  12-16-94
# 713               ufc 3: the american dream  09-09-94
# 714                       ufc 2: no way out  03-11-94
#
#                            LOCATION
# 0               Tampa, Florida, USA
# 1            Las Vegas, Nevada, USA
# 2                      Macau, China
# 3      New York City, New York, USA
# 4            Las Vegas, Nevada, USA
# ..                              ...
# 710            Casper, Wyoming, USA
# 711  Charlotte, North Carolina, USA
# 712            Tulsa, Oklahoma, USA
# 713  Charlotte, North Carolina, USA
# 714           Denver, Colorado, USA
#
# [715 rows x 3 columns]

# %% [markdown]
# ## Cleaning df_ufc_fight_results

# %%
df_ufc_fight_results = pd.read_csv('ufc_fight_results.csv')

# %%
df_ufc_fight_results
# Out:
#                                         EVENT  \
# 0     UFC Fight Night: Covington vs. Buckley
# 1     UFC Fight Night: Covington vs. Buckley
# 2     UFC Fight Night: Covington vs. Buckley
# 3     UFC Fight Night: Covington vs. Buckley
# 4     UFC Fight Night: Covington vs. Buckley
# ...                                       ...
# 7930                       UFC 2: No Way Out
# 7931                       UFC 2: No Way Out
# 7932                       UFC 2: No Way Out
# 7933                       UFC 2: No Way Out
# 7934                       UFC 2: No Way Out
#
#                                        BOUT OUTCOME             WEIGHTCLASS  \
# 0     Colby Covington  vs. Joaquin Buckley      L/W       Welterweight Bout
# 1       Cub Swanson  vs. Billy Quarantillo      W/L      Featherweight Bout
# 2              Manel Kape  vs. Bruno Silva      W/L          Flyweight Bout
# 3         Vitor Petrino  vs. Dustin Jacoby      L/W  Light Heavyweight Bout
# 4          Adrian Yanez  vs. Daniel Marcos      L/W       Bantamweight Bout
# ...                                     ...     ...                     ...
# 7930    Orlando Wiet  vs. Robert Lucarelli      W/L        Open Weight Bout
# 7931    Frank Hamaker  vs. Thaddeus Luster      W/L        Open Weight Bout
# 7932      Johnny Rhodes  vs. David Levicki      W/L        Open Weight Bout
# 7933         Patrick Smith  vs. Ray Wizard      W/L        Open Weight Bout
# 7934      Scott Morris  vs. Sean Daugherty      W/L        Open Weight Bout
#
#                         METHOD  ROUND   TIME        TIME FORMAT  \
# 0     TKO - Doctor's Stoppage       3   4:42  5 Rnd (5-5-5-5-5)
# 1                      KO/TKO       3   1:36      3 Rnd (5-5-5)
# 2                      KO/TKO       3   1:57      3 Rnd (5-5-5)
# 3                      KO/TKO       3   3:44      3 Rnd (5-5-5)
# 4            Decision - Split       3   5:00      3 Rnd (5-5-5)
# ...                        ...    ...    ...                ...
# 7930                   KO/TKO       1   2:50      No Time Limit
# 7931               Submission       1   4:52      No Time Limit
# 7932                   KO/TKO       1  12:13      No Time Limit
# 7933               Submission       1   0:58      No Time Limit
# 7934               Submission       1   0:20      No Time Limit
#
#               REFEREE                                            DETAILS  \
# 0     Dan Miragliotta                                      Cut above eye
# 1        Jason Herzog                         Punch to Head At Distance
# 2      Keith Peterson                       Punches to Head At Distance
# 3        Andrew Glenn                         Punch to Head At Distance
# 4      Keith Peterson  Derek Cleary 27 - 30.Chris Lee 29 - 28.Eric Co...
# ...               ...                                                ...
# 7930    John McCarthy                                  toCorner Stoppage
# 7931    John McCarthy                           Keylock From Half Guard
# 7932    John McCarthy    Punches to Head From GuardSubmission to Strikes
# 7933    John McCarthy                         Guillotine Choke Standing
# 7934    John McCarthy                       Guillotine Choke From Mount
#
#                                                     URL
# 0     http://ufcstats.com/fight-details/00c6a2ef07ca...
# 1     http://ufcstats.com/fight-details/752101555408...
# 2     http://ufcstats.com/fight-details/1a635a5e4551...
# 3     http://ufcstats.com/fight-details/7b1bc4ff776f...
# 4     http://ufcstats.com/fight-details/5238f6470d05...
# ...                                                 ...
# 7930  http://ufcstats.com/fight-details/3b020d4914b4...
# 7931  http://ufcstats.com/fight-details/d917c8c7461b...
# 7932  http://ufcstats.com/fight-details/ccee020be2e8...
# 7933  http://ufcstats.com/fight-details/4b9ae533ccb3...
# 7934  http://ufcstats.com/fight-details/4acab67848e7...
#
# [7935 rows x 11 columns]

# %%
df_ufc_fight_results = df_ufc_fight_results.drop(columns=['URL','DETAILS','REFEREE'])
df_ufc_fight_results['EVENT'] = df_ufc_fight_results['EVENT'].str.strip().str.lower()
df_ufc_fight_results['BOUT'] = df_ufc_fight_results['BOUT'].str.strip().str.lower()
df_ufc_fight_results['METHOD'] = df_ufc_fight_results['METHOD'].str.strip().str.lower()

# %%
def cv_time(time):
    minutes,seconds = time.split(':')
    return int(minutes)*60+int(seconds)

# %%
df_ufc_fight_results['TIME'] = df_ufc_fight_results['TIME'].apply(cv_time)
df_ufc_fight_results[['FIGHTER_1','FIGHTER_2']] = df_ufc_fight_results['BOUT'].str.split(' vs. ', expand=True)

# %%
df_ufc_fight_results['TIME FORMAT'].unique()
# Out:
# array(['5 Rnd (5-5-5-5-5)', '3 Rnd (5-5-5)', '3 Rnd + OT (5-5-5-5)',
#        '2 Rnd (5-5)', '1 Rnd + 2OT (15-3-3)', '1 Rnd + OT (12-3)',
#        '1 Rnd (12)', '1 Rnd + OT (15-3)', '1 Rnd (15)',
#        '1 Rnd + 2OT (24-3-3)', '1 Rnd (10)', '1 Rnd + OT (27-3)',
#        '1 Rnd (18)', '1 Rnd + OT (30-5)', '1 Rnd + OT (30-3)',
#        '1 Rnd (20)', '1 Rnd (30)', '1 Rnd + OT (31-5)', 'No Time Limit'],
#       dtype=object)

# %%
def cv_time_format(time_fm):
    if 'No Time Limit' in time_fm:
        return None, None, None, None
    rounds_info = time_fm.split(' Rnd')
    round_num = int(rounds_info[0])

    if '+' in rounds_info[1]:
        main, overtime = rounds_info[1].split('OT')
        main_round_time = overtime.strip(' ( )').split('-')[0]
        ot_round_time = overtime.strip(' ()').split('-')[1]
        num_ot_rounds = main.split(' ')[2].strip()
        return round_num, main_round_time, num_ot_rounds, ot_round_time
    else:
        main_round_time = rounds_info[1].strip(' ( )').split('-')[0]

        return round_num, main_round_time, 0, 0
df_ufc_fight_results[['Total_Rounds_Format', 'Main_round_time_Format', 'Num_overtime_rounds_Format', 'Overtime_round_time_Format']] = df_ufc_fight_results['TIME FORMAT'].apply(cv_time_format).apply(pd.Series)

# %%
df_ufc_fight_results
# Out:
#                                        EVENT  \
# 0     ufc fight night: covington vs. buckley
# 1     ufc fight night: covington vs. buckley
# 2     ufc fight night: covington vs. buckley
# 3     ufc fight night: covington vs. buckley
# 4     ufc fight night: covington vs. buckley
# ...                                      ...
# 7930                       ufc 2: no way out
# 7931                       ufc 2: no way out
# 7932                       ufc 2: no way out
# 7933                       ufc 2: no way out
# 7934                       ufc 2: no way out
#
#                                       BOUT OUTCOME             WEIGHTCLASS  \
# 0     colby covington  vs. joaquin buckley     L/W       Welterweight Bout
# 1       cub swanson  vs. billy quarantillo     W/L      Featherweight Bout
# 2              manel kape  vs. bruno silva     W/L          Flyweight Bout
# 3         vitor petrino  vs. dustin jacoby     L/W  Light Heavyweight Bout
# 4          adrian yanez  vs. daniel marcos     L/W       Bantamweight Bout
# ...                                    ...     ...                     ...
# 7930    orlando wiet  vs. robert lucarelli     W/L        Open Weight Bout
# 7931    frank hamaker  vs. thaddeus luster     W/L        Open Weight Bout
# 7932      johnny rhodes  vs. david levicki     W/L        Open Weight Bout
# 7933         patrick smith  vs. ray wizard     W/L        Open Weight Bout
# 7934      scott morris  vs. sean daugherty     W/L        Open Weight Bout
#
#                        METHOD  ROUND  TIME        TIME FORMAT  \
# 0     tko - doctor's stoppage      3   282  5 Rnd (5-5-5-5-5)
# 1                      ko/tko      3    96      3 Rnd (5-5-5)
# 2                      ko/tko      3   117      3 Rnd (5-5-5)
# 3                      ko/tko      3   224      3 Rnd (5-5-5)
# 4            decision - split      3   300      3 Rnd (5-5-5)
# ...                       ...    ...   ...                ...
# 7930                   ko/tko      1   170      No Time Limit
# 7931               submission      1   292      No Time Limit
# 7932                   ko/tko      1   733      No Time Limit
# 7933               submission      1    58      No Time Limit
# 7934               submission      1    20      No Time Limit
#
#              FIGHTER_1          FIGHTER_2  Total_Rounds_Format  \
# 0     colby covington     joaquin buckley                  5.0
# 1         cub swanson   billy quarantillo                  3.0
# 2          manel kape         bruno silva                  3.0
# 3       vitor petrino       dustin jacoby                  3.0
# 4        adrian yanez       daniel marcos                  3.0
# ...                ...                ...                  ...
# 7930     orlando wiet    robert lucarelli                  NaN
# 7931    frank hamaker     thaddeus luster                  NaN
# 7932    johnny rhodes       david levicki                  NaN
# 7933    patrick smith          ray wizard                  NaN
# 7934     scott morris      sean daugherty                  NaN
#
#      Main_round_time_Format Num_overtime_rounds_Format  \
# 0                         5                          0
# 1                         5                          0
# 2                         5                          0
# 3                         5                          0
# 4                         5                          0
# ...                     ...                        ...
# 7930                   None                       None
# 7931                   None                       None
# 7932                   None                       None
# 7933                   None                       None
# 7934                   None                       None
#
#      Overtime_round_time_Format
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 7930                       None
# 7931                       None
# 7932                       None
# 7933                       None
# 7934                       None
#
# [7935 rows x 14 columns]

# %%
df_ufc_fight_results['METHOD'].unique()
# Out:
# array(["tko - doctor's stoppage", 'ko/tko', 'decision - split',
#        'decision - unanimous', 'submission', 'could not continue',
#        'decision - majority', 'dq', 'overturned', 'other'], dtype=object)

# %%
df_ufc_fight_results['WEIGHTCLASS'].unique()
# Out:
# array(['Welterweight Bout', 'Featherweight Bout', 'Flyweight Bout',
#        'Light Heavyweight Bout', 'Bantamweight Bout', 'Lightweight Bout',
#        "Women's Flyweight Bout", "Women's Strawweight Bout",
#        'UFC Flyweight Title Bout', 'Heavyweight Bout',
#        'Catch Weight Bout', 'UFC Heavyweight Title Bout',
#        'Middleweight Bout', "Women's Bantamweight Bout",
#        'UFC Light Heavyweight Title Bout',
#        "UFC Women's Bantamweight Title Bout",
#        'UFC Bantamweight Title Bout', "UFC Women's Flyweight Title Bout",
#        'UFC Middleweight Title Bout', 'UFC Welterweight Title Bout',
#        'UFC Interim Heavyweight Title Bout', 'UFC Lightweight Title Bout',
#        "UFC Women's Strawweight Title Bout",
#        'UFC Featherweight Title Bout', "Women's Featherweight Bout",
#        'UFC Interim Featherweight Title Bout',
#        'UFC Interim Flyweight Title Bout',
#        'UFC Interim Bantamweight Title Bout',
#        "UFC Women's Featherweight Title Bout",
#        'UFC Interim Lightweight Title Bout',
#        'UFC Interim Middleweight Title Bout',
#        'Ultimate Fighter 28 Heavyweight Tournament Title Bout',
#        "Ultimate Fighter 28 Women's Featherweight Tournament Title Bout",
#        'Ultimate Fighter 27 Lightweight Tournament Title Bout',
#        'Ultimate Fighter 27 Featherweight Tournament Title Bout',
#        'UFC Interim Welterweight Title Bout',
#        'Ultimate Fighter 25 Welterweight Tournament Title Bout',
#        'Ultimate Fighter Latin America 3 Lightweight Tournament Title Bout',
#        'Ultimate Fighter 23 Light Heavyweight Tournament Title Bout',
#        "Ultimate Fighter 23 Women's Strawweight Tournament Title Bout",
#        'UFC Interim Light Heavyweight Title Bout',
#        'Ultimate Fighter 22 Lightweight Tournament Title Bout',
#        'Ultimate Fighter Latin America 2 Welterweight Tournament Title Bout',
#        'Ultimate Fighter Latin America 2 Lightweight Tournament Title Bout',
#        'Ultimate Fighter Brazil 4 Lightweight Tournament Title Bout',
#        'Ultimate Fighter Brazil 4 Bantamweight Tournament Title Bout',
#        'Ultimate Fighter 21 Welterweight Tournament Title Bout',
#        'Ultimate Fighter Latin America Featherweight Tournament Title Bout',
#        'Ultimate Fighter Latin America Bantamweight Tournament Title Bout',
#        'Ultimate Fighter China Featherweight Tournament Title Bout',
#        'Ultimate Fighter 19 Light Heavyweight Tournament Title Bout',
#        'Ultimate Fighter 19 Middleweight Tournament Title Bout',
#        'Ultimate Fighter Brazil 3 Heavyweight Tournament Title Bout',
#        'Ultimate Fighter Brazil 3 Middleweight Tournament Title Bout',
#        'TUF Nations Canada vs. Australia Middleweight Tournament Title Bout',
#        'TUF Nations Canada vs. Australia Welterweight Tournament Title Bout',
#        'Ultimate Fighter China Welterweight Tournament Title Bout',
#        "Ultimate Fighter 18 Women's Bantamweight Tournament Title Bout",
#        'Ultimate Fighter 18 Bantamweight Tournament Title Bout',
#        'Ultimate Fighter Brazil 2 Welterweight Tournament Title Bout',
#        'Ultimate Fighter 17 Middleweight Tournament Title Bout',
#        'Ultimate Fighter 16 Welterweight Tournament Title Bout',
#        'Ultimate Fighter Australia vs. UK Welterweight Tournament Title Bout',
#        'Ultimate Fighter Australia vs. UK Lightweight Tournament Title Bout',
#        'Ultimate Fighter Brazil 1 Middleweight Tournament Title Bout',
#        'Ultimate Fighter Brazil 1 Featherweight Tournament Title Bout',
#        'Ultimate Fighter 15 Lightweight Tournament Title Bout',
#        'Ultimate Fighter 14 Featherweight Tournament Title Bout',
#        'Ultimate Fighter 14 Bantamweight Tournament Title Bout',
#        'Ultimate Fighter 13 Welterweight Tournament Title Bout',
#        'Ultimate Fighter 12 Lightweight Tournament Title Bout',
#        'Ultimate Fighter 11 Middleweight Tournament Title Bout',
#        'Ultimate Fighter 10 Heavyweight Tournament Title Bout',
#        'Ultimate Fighter 9 Welterweight Tournament Title Bout',
#        'Ultimate Fighter 9 Lightweight Tournament Title Bout',
#        'Ultimate Fighter 8 Lightweight Tournament Title Bout',
#        'Ultimate Fighter 8 Light Heavyweight Tournament Title Bout',
#        'Ultimate Fighter 7 Middleweight Tournament Title Bout',
#        'Ultimate Fighter 6 Welterweight Tournament Title Bout',
#        'Ultimate Fighter 5 Lightweight Tournament Title Bout',
#        'Ultimate Fighter 4 Welterweight Tournament Title Bout',
#        'Ultimate Fighter 4 Middleweight Tournament Title Bout',
#        'Ultimate Fighter 3 Light Heavyweight Tournament Title Bout',
#        'Ultimate Fighter 3 Middleweight Tournament Title Bout',
#        'Ultimate Fighter 2 Heavyweight Tournament Title Bout',
#        'Ultimate Fighter 2 Welterweight Tournament Title Bout',
#        'Ultimate Fighter 1 Light Heavyweight Tournament Title Bout',
#        'Ultimate Fighter 1 Middleweight Tournament Title Bout',
#        'Super Heavyweight Bout',
#        'Ultimate Japan 2 Heavyweight Tournament Title Bout',
#        'Open Weight Bout', 'UFC 17 Middleweight Tournament Title Bout',
#        'Ultimate Japan Heavyweight Tournament Title Bout',
#        'UFC 15 Heavyweight Tournament Title Bout',
#        'UFC 14 Heavyweight Tournament Title Bout',
#        'UFC 14 Middleweight Tournament Title Bout',
#        'UFC 13 Heavyweight Tournament Title Bout',
#        'UFC 13 Lightweight Tournament Title Bout',
#        "Ultimate Ultimate '96 Tournament Title Bout",
#        'UFC 10 Tournament Title Bout', 'UFC Superfight Championship Bout',
#        'UFC 8 Tournament Title Bout',
#        "Ultimate Ultimate '95 Tournament Title Bout",
#        'UFC 7 Tournament Title Bout', 'UFC 6 Tournament Title Bout',
#        'UFC 5 Tournament Title Bout', 'UFC 4 Tournament Title Bout',
#        'UFC 3 Tournament Title Bout', 'UFC 2 Tournament Title Bout'],
#       dtype=object)

# %%
df_ufc_fight_results['gender'] = df_ufc_fight_results['WEIGHTCLASS'].apply(lambda x: 1 if 'Women' in x else 0)
df_ufc_fight_results['is_title_bout'] = df_ufc_fight_results['WEIGHTCLASS'].apply(lambda x: 1 if 'Title' in x else 0)

# %%
weight_class_list = [
    'Lightweight', 'Strawweight', 'Featherweight', 'Flyweight', 'Bantamweight', 
    'Welterweight', 'Middleweight', 'Light Heavyweight', 'Heavyweight', 
    'Super Heavyweight', 'Catch Weight', 'Open Weight'
]
def cv_weight_class(weight_class):
    for wc in weight_class_list:
        if wc in weight_class:
            return wc
    return None

df_ufc_fight_results['weight_class'] = df_ufc_fight_results['WEIGHTCLASS'].apply(cv_weight_class)

# %%
check = df_ufc_fight_results[df_ufc_fight_results['weight_class'].isna()]
check['EVENT']
# Out:
# 7821       ufc - ultimate ultimate '96
# 7839            ufc 10: the tournament
# 7848         ufc 9: motor city madness
# 7855           ufc 8: david vs goliath
# 7856           ufc 8: david vs goliath
# 7864       ufc - ultimate ultimate '95
# 7873       ufc 7: the brawl in buffalo
# 7874       ufc 7: the brawl in buffalo
# 7884        ufc 6: clash of the titans
# 7885        ufc 6: clash of the titans
# 7894    ufc 5: the return of the beast
# 7895    ufc 5: the return of the beast
# 7904    ufc 4: revenge of the warriors
# 7914         ufc 3: the american dream
# 7920                 ufc 2: no way out
# Name: EVENT, dtype: object

# %% [markdown]
# #### Drop all the superfight championship since there was no weightclass being introduced back in the day these matches took place

# %%
df_ufc_fight_results = df_ufc_fight_results[~df_ufc_fight_results['WEIGHTCLASS'].str.contains('Superfight Championship Bout', na=False)]

# %%
df_ufc_fight_results['fighter_1_result'] = df_ufc_fight_results['OUTCOME'].apply(lambda x: 'Win' if x.startswith('W') else 'L')
df_ufc_fight_results['fighter_2_results'] = df_ufc_fight_results['OUTCOME'].apply(lambda x: 'Win' if x.startswith('W') else 'L')
# Out:
# /tmp/ipykernel_530434/4285135627.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ufc_fight_results['fighter_1_result'] = df_ufc_fight_results['OUTCOME'].apply(lambda x: 'Win' if x.startswith('W') else 'L')
# /tmp/ipykernel_530434/4285135627.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ufc_fight_results['fighter_2_results'] = df_ufc_fight_results['OUTCOME'].apply(lambda x: 'Win' if x.startswith('W') else 'L')

# %%
df_ufc_fight_results.isnull().sum()
# Out:
# EVENT                          0
# BOUT                           0
# OUTCOME                        0
# WEIGHTCLASS                    0
# METHOD                         0
# ROUND                          0
# TIME                           0
# TIME FORMAT                    0
# FIGHTER_1                      0
# FIGHTER_2                      0
# Total_Rounds_Format           31
# Main_round_time_Format        31
# Num_overtime_rounds_Format    31
# Overtime_round_time_Format    31
# gender                         0
# is_title_bout                  0
# weight_class                  10
# fighter_1_result               0
# fighter_2_results              0
# dtype: int64

# %%
df_ufc_fight_results.to_csv('ufc_fight_results_processed.csv')
