# %%
import numpy as np
import pandas as pd
from datetime import datetime

# %%
df_event_details_og = pd.read_csv('/home/duyle/Documents/VSC/Project_DAP391/og_dataset/ufc_event_details.csv')
df_results_og= pd.read_csv('/home/duyle/Documents/VSC/Project_DAP391/og_dataset/ufc_fight_results.csv')
df_stats_og= pd.read_csv('/home/duyle/Documents/VSC/Project_DAP391/og_dataset/ufc_fight_stats.csv')
df_ufc_fighter_tott = pd.read_csv('/home/duyle/Documents/VSC/Project_DAP391/og_dataset/ufc_fighter_tott.csv')

# %%
df_ufc_fighter_tott.head()
# Out:
#                FIGHTER  HEIGHT    WEIGHT REACH    STANCE           DOB  \
# 0            Tom Aaron      --  155 lbs.    --       NaN  Jul 13, 1978
# 1         Danny Abbadi  5' 11"  155 lbs.    --  Orthodox  Jul 03, 1983
# 2         David Abbott   6' 0"  265 lbs.    --    Switch            --
# 3  Shamil Abdurakhimov   6' 3"  235 lbs.   76"  Orthodox  Sep 02, 1981
# 4         Hiroyuki Abe   5' 6"  145 lbs.    --  Orthodox            --
#
#                                                  URL
# 0  http://ufcstats.com/fighter-details/93fe7332d1...
# 1  http://ufcstats.com/fighter-details/15df64c02b...
# 2  http://ufcstats.com/fighter-details/b361180739...
# 3  http://ufcstats.com/fighter-details/2f5cbecbbe...
# 4  http://ufcstats.com/fighter-details/c0ed7b2081...

# %%
df_event_details_og.head()
# Out:
#                                     EVENT  \
# 0  UFC Fight Night: Covington vs. Buckley
# 1            UFC 310: Pantoja vs. Asakura
# 2     UFC Fight Night: Yan vs. Figueiredo
# 3               UFC 309: Jones vs. Miocic
# 4       UFC Fight Night: Magny vs. Prates
#
#                                                  URL               DATE  \
# 0  http://ufcstats.com/event-details/72c9c2eadfc3...  December 14, 2024
# 1  http://ufcstats.com/event-details/ad23903ef3af...  December 07, 2024
# 2  http://ufcstats.com/event-details/e955046551f8...  November 23, 2024
# 3  http://ufcstats.com/event-details/daff32bc96d1...  November 16, 2024
# 4  http://ufcstats.com/event-details/585f9ffdb0cd...  November 09, 2024
#
#                        LOCATION
# 0           Tampa, Florida, USA
# 1        Las Vegas, Nevada, USA
# 2                  Macau, China
# 3  New York City, New York, USA
# 4        Las Vegas, Nevada, USA

# %%
df_results_og.head()
# Out:
#                                      EVENT  \
# 0  UFC Fight Night: Covington vs. Buckley
# 1  UFC Fight Night: Covington vs. Buckley
# 2  UFC Fight Night: Covington vs. Buckley
# 3  UFC Fight Night: Covington vs. Buckley
# 4  UFC Fight Night: Covington vs. Buckley
#
#                                     BOUT OUTCOME             WEIGHTCLASS  \
# 0  Colby Covington  vs. Joaquin Buckley      L/W       Welterweight Bout
# 1    Cub Swanson  vs. Billy Quarantillo      W/L      Featherweight Bout
# 2           Manel Kape  vs. Bruno Silva      W/L          Flyweight Bout
# 3      Vitor Petrino  vs. Dustin Jacoby      L/W  Light Heavyweight Bout
# 4       Adrian Yanez  vs. Daniel Marcos      L/W       Bantamweight Bout
#
#                      METHOD  ROUND  TIME        TIME FORMAT          REFEREE  \
# 0  TKO - Doctor's Stoppage       3  4:42  5 Rnd (5-5-5-5-5)  Dan Miragliotta
# 1                   KO/TKO       3  1:36      3 Rnd (5-5-5)     Jason Herzog
# 2                   KO/TKO       3  1:57      3 Rnd (5-5-5)   Keith Peterson
# 3                   KO/TKO       3  3:44      3 Rnd (5-5-5)     Andrew Glenn
# 4         Decision - Split       3  5:00      3 Rnd (5-5-5)   Keith Peterson
#
#                                              DETAILS  \
# 0                                      Cut above eye
# 1                         Punch to Head At Distance
# 2                       Punches to Head At Distance
# 3                         Punch to Head At Distance
# 4  Derek Cleary 27 - 30.Chris Lee 29 - 28.Eric Co...
#
#                                                  URL
# 0  http://ufcstats.com/fight-details/00c6a2ef07ca...
# 1  http://ufcstats.com/fight-details/752101555408...
# 2  http://ufcstats.com/fight-details/1a635a5e4551...
# 3  http://ufcstats.com/fight-details/7b1bc4ff776f...
# 4  http://ufcstats.com/fight-details/5238f6470d05...

# %%
df_stats_og.head()
# Out:
#                                     EVENT  \
# 0  UFC Fight Night: Covington vs. Buckley
# 1  UFC Fight Night: Covington vs. Buckley
# 2  UFC Fight Night: Covington vs. Buckley
# 3  UFC Fight Night: Covington vs. Buckley
# 4  UFC Fight Night: Covington vs. Buckley
#
#                                   BOUT    ROUND          FIGHTER   KD  \
# 0  Colby Covington vs. Joaquin Buckley  Round 1  Colby Covington  0.0
# 1  Colby Covington vs. Joaquin Buckley  Round 2  Colby Covington  0.0
# 2  Colby Covington vs. Joaquin Buckley  Round 3  Colby Covington  0.0
# 3  Colby Covington vs. Joaquin Buckley  Round 1  Joaquin Buckley  0.0
# 4  Colby Covington vs. Joaquin Buckley  Round 2  Joaquin Buckley  0.0
#
#    SIG.STR. SIG.STR. % TOTAL STR.      TD TD %  SUB.ATT  REV.  CTRL      HEAD  \
# 0  10 of 51        19%   10 of 51  0 of 2   0%      0.0   0.0  0:22   5 of 42
# 1  19 of 50        38%   25 of 56  1 of 3  33%      0.0   0.0  1:28  13 of 43
# 2   8 of 23        34%   36 of 54  0 of 3   0%      0.0   0.0  1:50   8 of 23
# 3  23 of 55        41%   23 of 55  0 of 0  ---      0.0   0.0  0:09  18 of 47
# 4  28 of 55        50%   29 of 56  0 of 1   0%      0.0   0.0  0:01  20 of 46
#
#      BODY     LEG  DISTANCE  CLINCH  GROUND
# 0  4 of 6  1 of 3  10 of 51  0 of 0  0 of 0
# 1  4 of 5  2 of 2  17 of 48  0 of 0  2 of 2
# 2  0 of 0  0 of 0   6 of 21  0 of 0  2 of 2
# 3  4 of 7  1 of 1  20 of 49  1 of 2  2 of 4
# 4  6 of 7  2 of 2  24 of 50  4 of 5  0 of 0

# %%
df_results = pd.read_csv('/home/duyle/Documents/VSC/Project_DAP391/ufc_fight_results_processed.csv')
df_stats = pd.read_csv('fight_stats_with_weghtclass_date_location.csv')
df_fighters = pd.read_csv('fighters.csv')

# %%
df_results
# Out:
#                                        EVENT  \
# 0     ufc fight night: covington vs. buckley
# 1     ufc fight night: covington vs. buckley
# 2     ufc fight night: covington vs. buckley
# 3     ufc fight night: covington vs. buckley
# 4     ufc fight night: covington vs. buckley
# ...                                      ...
# 7782              ufc 13: the ultimate force
# 7783              ufc 13: the ultimate force
# 7784              ufc 13: the ultimate force
# 7785              ufc 13: the ultimate force
# 7786              ufc 13: the ultimate force
#
#                                       BOUT OUTCOME                   METHOD  \
# 0     colby covington  vs. joaquin buckley     L/W  tko - doctor's stoppage
# 1       cub swanson  vs. billy quarantillo     W/L                   ko/tko
# 2              manel kape  vs. bruno silva     W/L                   ko/tko
# 3         vitor petrino  vs. dustin jacoby     L/W                   ko/tko
# 4          adrian yanez  vs. daniel marcos     L/W         decision - split
# ...                                    ...     ...                      ...
# 7782    steven graham  vs. dmitri stepanov     W/L               submission
# 7783          enson inoue  vs. royce alger     W/L               submission
# 7784   guy mezger  vs. christophe leninger     W/L     decision - unanimous
# 7785       jack nilson  vs. saeed hosseini     W/L                   ko/tko
# 7786         tito ortiz  vs. wes albritton     W/L                   ko/tko
#
#       ROUND  TIME        TIME FORMAT        FIGHTER_1            FIGHTER_2  \
# 0         3   282  5 Rnd (5-5-5-5-5)  colby covington      joaquin buckley
# 1         3    96      3 Rnd (5-5-5)      cub swanson    billy quarantillo
# 2         3   117      3 Rnd (5-5-5)       manel kape          bruno silva
# 3         3   224      3 Rnd (5-5-5)    vitor petrino        dustin jacoby
# 4         3   300      3 Rnd (5-5-5)     adrian yanez        daniel marcos
# ...     ...   ...                ...              ...                  ...
# 7782      1    90  1 Rnd + OT (12-3)    steven graham      dmitri stepanov
# 7783      1    96  1 Rnd + OT (12-3)      enson inoue          royce alger
# 7784      2   180  1 Rnd + OT (12-3)       guy mezger  christophe leninger
# 7785      1    83  1 Rnd + OT (12-3)      jack nilson       saeed hosseini
# 7786      1    31  1 Rnd + OT (12-3)       tito ortiz        wes albritton
#
#       Total_Rounds_Format  Main_round_time_Format  Num_overtime_rounds_Format  \
# 0                     5.0                       5                         0.0
# 1                     3.0                       5                         0.0
# 2                     3.0                       5                         0.0
# 3                     3.0                       5                         0.0
# 4                     3.0                       5                         0.0
# ...                   ...                     ...                         ...
# 7782                  1.0                      12                         NaN
# 7783                  1.0                      12                         NaN
# 7784                  1.0                      12                         NaN
# 7785                  1.0                      12                         NaN
# 7786                  1.0                      12                         NaN
#
#       Overtime_round_time_Format  gender  is_title_bout       weight_class  \
# 0                              0       0              0       welterweight
# 1                              0       0              0      featherweight
# 2                              0       0              0          flyweight
# 3                              0       0              0  light heavyweight
# 4                              0       0              0       bantamweight
# ...                          ...     ...            ...                ...
# 7782                           3       0              0        heavyweight
# 7783                           3       0              0        lightweight
# 7784                           3       0              0        lightweight
# 7785                           3       0              0        lightweight
# 7786                           3       0              0        lightweight
#
#      fighter_1_result fighter_2_result
# 0                   L                W
# 1                   W                L
# 2                   W                L
# 3                   L                W
# 4                   L                W
# ...               ...              ...
# 7782                W                L
# 7783                W                L
# 7784                W                L
# 7785                W                L
# 7786                W                L
#
# [7787 rows x 18 columns]

# %%
# df_results = df_results.drop(columns = 'BOUT')

# %%
df_results['METHOD'].unique()
# Out:
# array(["tko - doctor's stoppage", 'ko/tko', 'decision - split',
#        'decision - unanimous', 'submission', 'could not continue',
#        'decision - majority', 'dq', 'overturned', 'other'], dtype=object)

# %%
method_mapping_numeric = {
    "ko/tko": 0,
    "tko - doctor's stoppage": 0,
    "submission": 1,
    "decision - unanimous": 2,
    "decision - split": 2,
    "decision - majority": 2,
    "could not continue": 0,
    "dq": 3,
    "overturned": 4,
    "other": 4
}

# %%
result_mapping_numeric = { 'W': 1, 'L':0,'NC':3,'D':4}

# %%
df_results['method_label'] = df_results['METHOD'].map(method_mapping_numeric)

# %%
df_results['fighter_1_result'] = df_results['fighter_1_result'].map(result_mapping_numeric)
df_results['fighter_2_result'] = df_results['fighter_2_result'].map(result_mapping_numeric)

# %%
df_results = df_results.drop(columns = ['METHOD'])

# %%
df_results['weight_class'].unique()
# Out:
# array(['welterweight', 'featherweight', 'flyweight', 'light heavyweight',
#        'bantamweight', 'lightweight', 'strawweight', 'heavyweight',
#        'catch weight', 'middleweight', 'open weight'], dtype=object)

# %%
df_results['weight_class'] = df_results['weight_class'].fillna('open weight')

# %%
weightclass_mapping = {'strawweight': 0,'flyweight': 1,'bantamweight': 2,'featherweight': 3,'lightweight': 4,'welterweight': 5,
                       'middleweight': 6, 'light heavyweight': 7, 'heavyweight': 8, 'catch weight': 9, 'open weight': 10}

# %%
df_results['weightclass_numeric'] = df_results['weight_class'].map(weightclass_mapping)

# %%
df_results
# Out:
#                                        EVENT  \
# 0     ufc fight night: covington vs. buckley
# 1     ufc fight night: covington vs. buckley
# 2     ufc fight night: covington vs. buckley
# 3     ufc fight night: covington vs. buckley
# 4     ufc fight night: covington vs. buckley
# ...                                      ...
# 7782              ufc 13: the ultimate force
# 7783              ufc 13: the ultimate force
# 7784              ufc 13: the ultimate force
# 7785              ufc 13: the ultimate force
# 7786              ufc 13: the ultimate force
#
#                                       BOUT OUTCOME  ROUND  TIME  \
# 0     colby covington  vs. joaquin buckley     L/W      3   282
# 1       cub swanson  vs. billy quarantillo     W/L      3    96
# 2              manel kape  vs. bruno silva     W/L      3   117
# 3         vitor petrino  vs. dustin jacoby     L/W      3   224
# 4          adrian yanez  vs. daniel marcos     L/W      3   300
# ...                                    ...     ...    ...   ...
# 7782    steven graham  vs. dmitri stepanov     W/L      1    90
# 7783          enson inoue  vs. royce alger     W/L      1    96
# 7784   guy mezger  vs. christophe leninger     W/L      2   180
# 7785       jack nilson  vs. saeed hosseini     W/L      1    83
# 7786         tito ortiz  vs. wes albritton     W/L      1    31
#
#             TIME FORMAT        FIGHTER_1            FIGHTER_2  \
# 0     5 Rnd (5-5-5-5-5)  colby covington      joaquin buckley
# 1         3 Rnd (5-5-5)      cub swanson    billy quarantillo
# 2         3 Rnd (5-5-5)       manel kape          bruno silva
# 3         3 Rnd (5-5-5)    vitor petrino        dustin jacoby
# 4         3 Rnd (5-5-5)     adrian yanez        daniel marcos
# ...                 ...              ...                  ...
# 7782  1 Rnd + OT (12-3)    steven graham      dmitri stepanov
# 7783  1 Rnd + OT (12-3)      enson inoue          royce alger
# 7784  1 Rnd + OT (12-3)       guy mezger  christophe leninger
# 7785  1 Rnd + OT (12-3)      jack nilson       saeed hosseini
# 7786  1 Rnd + OT (12-3)       tito ortiz        wes albritton
#
#       Total_Rounds_Format  Main_round_time_Format  Num_overtime_rounds_Format  \
# 0                     5.0                       5                         0.0
# 1                     3.0                       5                         0.0
# 2                     3.0                       5                         0.0
# 3                     3.0                       5                         0.0
# 4                     3.0                       5                         0.0
# ...                   ...                     ...                         ...
# 7782                  1.0                      12                         NaN
# 7783                  1.0                      12                         NaN
# 7784                  1.0                      12                         NaN
# 7785                  1.0                      12                         NaN
# 7786                  1.0                      12                         NaN
#
#       Overtime_round_time_Format  gender  is_title_bout       weight_class  \
# 0                              0       0              0       welterweight
# 1                              0       0              0      featherweight
# 2                              0       0              0          flyweight
# 3                              0       0              0  light heavyweight
# 4                              0       0              0       bantamweight
# ...                          ...     ...            ...                ...
# 7782                           3       0              0        heavyweight
# 7783                           3       0              0        lightweight
# 7784                           3       0              0        lightweight
# 7785                           3       0              0        lightweight
# 7786                           3       0              0        lightweight
#
#       fighter_1_result  fighter_2_result  method_label  weightclass_numeric
# 0                    0                 1             0                    5
# 1                    1                 0             0                    3
# 2                    1                 0             0                    1
# 3                    0                 1             0                    7
# 4                    0                 1             2                    2
# ...                ...               ...           ...                  ...
# 7782                 1                 0             1                    8
# 7783                 1                 0             1                    4
# 7784                 1                 0             2                    4
# 7785                 1                 0             0                    4
# 7786                 1                 0             0                    4
#
# [7787 rows x 19 columns]

# %%
df_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   EVENT                       7787 non-null   object
#  1   BOUT                        7787 non-null   object
#  2   OUTCOME                     7787 non-null   object
#  3   ROUND                       7787 non-null   int64
#  4   TIME                        7787 non-null   int64
#  5   TIME FORMAT                 7787 non-null   object
#  6   FIGHTER_1                   7787 non-null   object
#  7   FIGHTER_2                   7787 non-null   object
#  8   Total_Rounds_Format         7787 non-null   float64
#  9   Main_round_time_Format      7787 non-null   int64
#  10  Num_overtime_rounds_Format  7708 non-null   float64
#  11  Overtime_round_time_Format  7787 non-null   int64
#  12  gender                      7787 non-null   int64
#  13  is_title_bout               7787 non-null   int64
#  14  weight_class                7787 non-null   object
#  15  fighter_1_result            7787 non-null   int64
#  16  fighter_2_result            7787 non-null   int64
#  17  method_label                7787 non-null   int64
#  18  weightclass_numeric         7787 non-null   int64
# dtypes: float64(2), int64(10), object(7)
# memory usage: 1.1+ MB

# %%
df_results.to_csv('ufc_fight_results_processed_official.csv', index=False)

# %% [markdown]
# ## df stats

# %%
df_stats.columns
# Out:
# Index(['EVENT', 'BOUT', 'ROUND', 'FIGHTER', 'KD', 'SIG.STR. %', 'TD %',
#        'SUB.ATT', 'REV.', 'CTRL', 'sig_str_attempt', 'sig_str_land',
#        'total_str_attempt', 'total_str_land', 'touchdown_attempt',
#        'takedown_land', 'total_leg_attempt', 'total_leg_land',
#        'total_distance_strike_attempt', 'total_distance_strike_land',
#        'total_body_attempt', 'total_body_land', 'total_clinch_attempt',
#        'total_clinch_land', 'total_ground_attempt', 'total_ground_land',
#        'total_head_attempt', 'total_head_land', 'weight_class', 'gender',
#        'is_title_bout', 'DATE', 'LOCATION'],
#       dtype='object')

# %% [markdown]
# ### df fighters

# %%
df_fighters = pd.read_csv('fighters.csv')

# %%
df_fighters.iloc[:5,  5:]
# Out:
#    Submissions  First_Round_Finishes Striking_Accuracy Takedown_Accuracy  \
# 0            0                     0               38%               NaN
# 1            0                     0               20%                0%
# 2            0                     0               39%               NaN
# 3            0                     4               52%               80%
# 4            1                     6               55%               NaN
#
#    Sig_Str_Landed Total  Sig_Str_Attempted Total  Takedowns_Landed_Total  \
# 0                    59                      155                     0.0
# 1                    45                      225                     NaN
# 2                    12                       31                     0.0
# 3                   102                      197                     3.0
# 4                    77                      141                     0.0
#
#    Takedowns_Attempted_Total  Sig_Strikes_Per Min  Takedown_Avg_Per Min  ...  \
# 0                          0                 3.29                   0.0  ...
# 1                          2                 3.00                   0.0  ...
# 2                          0                 2.41                   0.0  ...
# 3                          5                 3.40                   2.0  ...
# 4                          0                 6.61                   0.0  ...
#
#   Sig_Strikes_While_Clinched  Sig_Strikes_While_Grounded  Sig_Strikes_Head  \
# 0                    14(24%)                       3(5%)           51(86%)
# 1                      0(0%)                       0(0%)           26(58%)
# 2                     7(58%)                       1(8%)          12(100%)
# 3                      2(2%)                     30(29%)           76(75%)
# 4                      2(3%)                     47(61%)           74(96%)
#
#    Sig_Strikes_Body Sig_Strikes_Leg Win_by_KO/TKO Win_by_Decision  \
# 0            8(14%)           0(0%)         0(0%)           0(0%)
# 1            8(18%)         11(24%)         0(0%)           0(0%)
# 2             0(0%)           0(0%)         0(0%)           0(0%)
# 3             8(8%)         18(18%)       5(100%)           0(0%)
# 4             2(3%)           1(1%)        6(86%)           0(0%)
#
#   Win_by_Submission                   Place_of_Birth  Octagon_Debut
# 0             0(0%)           Orlando, United States  Jun. 24, 2006
# 1             0(0%)                       Kazakhstan  Feb. 11, 2025
# 2             0(0%)  Huntington Beach, United States  Jul. 14, 1995
# 3             0(0%)                            Egypt  Jul. 30, 2022
# 4            1(14%)        Pittsburgh, United States   Nov. 9, 2024
#
# [5 rows x 27 columns]

# %%
df_fighters[['Wins', 'Losses', 'Draws']] = df_fighters['Record'].str.extract(r'(\d+)-(\d+)-(\d+)').astype(float)
df_fighters = df_fighters.drop(columns=['Record'])

# %%
percentage_columns = ['Striking_Accuracy', 'Takedown_Accuracy','Sig_Str_Def','Takedown_Def']
for col in percentage_columns:
    df_fighters[col] = df_fighters[col].str.rstrip('%').astype(float)/100

# %%
strike_columns = [
    'Sig_Str_Landed Total', 'Sig_Strikes_While_Clinched','Sig_Strikes_While_Standing',
    'Sig_Strikes_While_Grounded', 'Sig_Strikes_Head',
    'Sig_Strikes_Body', 'Sig_Strikes_Leg',
    'Win_by_KO/TKO', 'Win_by_Decision', 'Win_by_Submission'
]
for col in strike_columns:
    if df_fighters[col].dtype == 'object':
        df_fighters[[col + '_Total', col + '_Percent']] = df_fighters[col].str.extract(r'(\d+)\((\d+)%\)').astype(float)
        df_fighters[col + '_Percent'] = df_fighters[col + '_Percent'].fillna(0) 
        df_fighters[col + '_Percent'] = df_fighters[col + '_Percent'] / 100
    else:
        df_fighters[col + '_Total'] = df_fighters[col] 
        df_fighters[col + '_Percent'] = 0

# %%
df_fighters = df_fighters.drop(columns=[col for col in strike_columns if col in df_fighters.columns])

# %%
def cv_time(time):
    if isinstance(time, str):
        parts = time.split(':')
        if len(parts) == 2:
            minutes, seconds = parts
            if minutes.isdigit() and seconds.isdigit():
                return int(minutes) * 60 + int(seconds)
    return 0
df_fighters['Avg_Fight_Time'] = df_fighters['Avg_Fight_Time'].apply(cv_time)

# %%
df_fighters[df_fighters['Sig_Str_Def'].isna()].iloc[:10,8:]
# Out:
#      Sig_Str_Attempted Total  Takedowns_Landed_Total  \
# 13                         0                     0.0
# 16                         0                     0.0
# 19                         0                     0.0
# 20                         0                     0.0
# 39                         0                     0.0
# 43                         0                     0.0
# 59                         0                     0.0
# 61                         0                     0.0
# 97                         0                     0.0
# 100                        0                     0.0
#
#      Takedowns_Attempted_Total  Sig_Strikes_Per Min  Takedown_Avg_Per Min  \
# 13                           0                  0.0                   0.0
# 16                           0                  0.0                   0.0
# 19                           0                  0.0                   0.0
# 20                           0                  0.0                   0.0
# 39                           0                  0.0                   0.0
# 43                           0                  0.0                   0.0
# 59                           0                  0.0                   0.0
# 61                           0                  0.0                   0.0
# 97                           0                  0.0                   0.0
# 100                          0                  0.0                   0.0
#
#      Sig_Str_Def  Knockdown_Avg  Sig_Strikes_Absorbed_Per_Min  \
# 13           NaN            NaN                           NaN
# 16           NaN            NaN                           NaN
# 19           NaN            NaN                           NaN
# 20           NaN            NaN                           NaN
# 39           NaN            NaN                           NaN
# 43           NaN            NaN                           NaN
# 59           NaN            NaN                           NaN
# 61           NaN            NaN                           NaN
# 97           NaN            NaN                           NaN
# 100          NaN            NaN                           NaN
#
#      Sub_Avg_Per_Min  Takedown_Def  ...  Sig_Strikes_Body_Total  \
# 13               NaN           NaN  ...                     NaN
# 16               NaN           NaN  ...                     NaN
# 19               NaN           NaN  ...                     0.0
# 20               NaN           NaN  ...                     NaN
# 39               NaN           NaN  ...                     NaN
# 43               NaN           NaN  ...                     NaN
# 59               NaN           NaN  ...                     NaN
# 61               NaN           NaN  ...                     NaN
# 97               NaN           NaN  ...                     NaN
# 100              NaN           NaN  ...                     NaN
#
#     Sig_Strikes_Body_Percent Sig_Strikes_Leg_Total  Sig_Strikes_Leg_Percent  \
# 13                       0.0                   NaN                      0.0
# 16                       0.0                   NaN                      0.0
# 19                       0.0                   0.0                      0.0
# 20                       0.0                   NaN                      0.0
# 39                       0.0                   NaN                      0.0
# 43                       0.0                   NaN                      0.0
# 59                       0.0                   NaN                      0.0
# 61                       0.0                   NaN                      0.0
# 97                       0.0                   NaN                      0.0
# 100                      0.0                   NaN                      0.0
#
#      Win_by_KO/TKO_Total  Win_by_KO/TKO_Percent  Win_by_Decision_Total  \
# 13                   0.0                    0.0                    0.0
# 16                   0.0                    0.0                    0.0
# 19                   0.0                    0.0                    0.0
# 20                   0.0                    0.0                    0.0
# 39                   0.0                    0.0                    0.0
# 43                   0.0                    0.0                    0.0
# 59                   0.0                    0.0                    0.0
# 61                   0.0                    0.0                    0.0
# 97                   0.0                    0.0                    0.0
# 100                  0.0                    0.0                    0.0
#
#      Win_by_Decision_Percent  Win_by_Submission_Total  \
# 13                       0.0                      0.0
# 16                       0.0                      0.0
# 19                       0.0                      0.0
# 20                       0.0                      0.0
# 39                       0.0                      0.0
# 43                       0.0                      0.0
# 59                       0.0                      0.0
# 61                       0.0                      0.0
# 97                       0.0                      0.0
# 100                      0.0                      0.0
#
#      Win_by_Submission_Percent
# 13                         0.0
# 16                         0.0
# 19                         0.0
# 20                         0.0
# 39                         0.0
# 43                         0.0
# 59                         0.0
# 61                         0.0
# 97                         0.0
# 100                        0.0
#
# [10 rows x 36 columns]

# %%
df_fighters['Takedowns_Landed_Total'] = df_fighters['Takedowns_Landed_Total'].fillna('0').astype(float)

# %%
df_fighters['Weight_Class'] = df_fighters['Weight_Class'].fillna('0')

# %%
df_fighters['Striking_Accuracy'] = df_fighters['Striking_Accuracy'].fillna('0').astype(float)
df_fighters['Takedown_Accuracy'] = df_fighters['Takedown_Accuracy'].fillna('0').astype(float)
df_fighters['Sig_Strikes_Per Min'] = df_fighters['Sig_Strikes_Per Min'].fillna('0').astype(float)
df_fighters['Takedown_Avg_Per Min'] = df_fighters['Takedown_Avg_Per Min'].fillna('0').astype(float)
df_fighters['Takedown_Avg_Per Min'] = df_fighters['Takedown_Avg_Per Min'].fillna('0').astype(float)
df_fighters['Sig_Str_Def'] = df_fighters['Sig_Str_Def'].fillna('0').astype(float)

# %%
columns_to_fill = [
    'Knockdown_Avg',
    'Sig_Strikes_Absorbed_Per_Min',
    'Sub_Avg_Per_Min',
    'Takedown_Def',
    'Wins',
    'Losses',
    'Draws',
    'Sig_Strikes_While_Clinched_Total',
    'Sig_Strikes_While_Standing_Total',
    'Sig_Strikes_While_Grounded_Total',
    'Sig_Strikes_Head_Total',
    'Sig_Strikes_Body_Total',
    'Sig_Strikes_Leg_Total',
]

# %%
for col in columns_to_fill:
    df_fighters[col] = df_fighters[col].fillna('0').astype(float)

# %%
df_fighters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3015 entries, 0 to 3014
# Data columns (total 44 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Name                                3015 non-null   object
#  1   Nickname                            1786 non-null   object
#  2   Weight_Class                        3015 non-null   object
#  3   Knockouts                           3015 non-null   int64
#  4   Submissions                         3015 non-null   int64
#  5   First_Round_Finishes                3015 non-null   int64
#  6   Striking_Accuracy                   3015 non-null   float64
#  7   Takedown_Accuracy                   3015 non-null   float64
#  8   Sig_Str_Attempted Total             3015 non-null   int64
#  9   Takedowns_Landed_Total              3015 non-null   float64
#  10  Takedowns_Attempted_Total           3015 non-null   int64
#  11  Sig_Strikes_Per Min                 3015 non-null   float64
#  12  Takedown_Avg_Per Min                3015 non-null   float64
#  13  Sig_Str_Def                         3015 non-null   float64
#  14  Knockdown_Avg                       3015 non-null   float64
#  15  Sig_Strikes_Absorbed_Per_Min        3015 non-null   float64
#  16  Sub_Avg_Per_Min                     3015 non-null   float64
#  17  Takedown_Def                        3015 non-null   float64
#  18  Avg_Fight_Time                      3015 non-null   int64
#  19  Place_of_Birth                      2830 non-null   object
#  20  Octagon_Debut                       3015 non-null   object
#  21  Wins                                3015 non-null   float64
#  22  Losses                              3015 non-null   float64
#  23  Draws                               3015 non-null   float64
#  24  Sig_Str_Landed Total_Total          3015 non-null   int64
#  25  Sig_Str_Landed Total_Percent        3015 non-null   int64
#  26  Sig_Strikes_While_Clinched_Total    3015 non-null   float64
#  27  Sig_Strikes_While_Clinched_Percent  3015 non-null   float64
#  28  Sig_Strikes_While_Standing_Total    3015 non-null   float64
#  29  Sig_Strikes_While_Standing_Percent  3015 non-null   float64
#  30  Sig_Strikes_While_Grounded_Total    3015 non-null   float64
#  31  Sig_Strikes_While_Grounded_Percent  3015 non-null   float64
#  32  Sig_Strikes_Head_Total              3015 non-null   float64
#  33  Sig_Strikes_Head_Percent            3015 non-null   float64
#  34  Sig_Strikes_Body_Total              3015 non-null   float64
#  35  Sig_Strikes_Body_Percent            3015 non-null   float64
#  36  Sig_Strikes_Leg_Total               3015 non-null   float64
#  37  Sig_Strikes_Leg_Percent             3015 non-null   float64
#  38  Win_by_KO/TKO_Total                 3015 non-null   float64
#  39  Win_by_KO/TKO_Percent               3015 non-null   float64
#  40  Win_by_Decision_Total               3015 non-null   float64
#  41  Win_by_Decision_Percent             3015 non-null   float64
#  42  Win_by_Submission_Total             3015 non-null   float64
#  43  Win_by_Submission_Percent           3015 non-null   float64
# dtypes: float64(31), int64(8), object(5)
# memory usage: 1.0+ MB

# %%
df_fighters.to_csv('fighters_processed.csv', index=False)
